# %% [markdown]
# # Install the environment

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes

# %%
# !conda --version
# !python --version
# Out:
# conda 4.10.3
# Python 3.6.13 :: Anaconda, Inc.

# %%
# !conda install -c pytorch pytorch=1.7.1 torchvision cudatoolkit=10.2 --yes

# %% [markdown]
# # Clone the Repo and Download resources for the Demos

# %%
# !git clone --recursive https://github.com/RenYurui/Neural-Texture-Extraction-Distribution.git
# Out:
# rm: cannot remove 'Neural-Texture-Extraction-Distribution': No such file or directory
# Cloning into 'Neural-Texture-Extraction-Distribution'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 105 (delta 22), reused 97 (delta 17), pack-reused 0
# Receiving objects: 100% (105/105), 68.40 KiB | 2.53 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# Submodule 'third_part/mmdetection' (https://github.com/open-mmlab/mmdetection.git) registered for path 'third_part/mmdetection'
# Cloning into '/content/Neural-Texture-Extraction-Distribution/third_part/mmdetection'...
# remote: Enumerating objects: 24305, done.
# remote: Total 24305 (delta 0), reused 0 (delta 0), pack-reused 24305
# Receiving objects: 100% (24305/24305), 37.47 MiB | 27.00 MiB/s, done.
# Resolving deltas: 100% (17013/17013), done.
# ...

# %%
# %%bash
# cd Neural-Texture-Extraction-Distribution
# pip install -r requirements.txt

# %%
# %%bash
# ls
# cd Neural-Texture-Extraction-Distribution/scripts
# chmod +x download_demos.sh
# ./download_demos.sh

# %% [markdown]
# # Pose Transfer Demo

# %%
# %%bash
# cd Neural-Texture-Extraction-Distribution
# PATH_TO_OUTPUT=./demo_results # save results in ./Neural-Texture-Extraction-Distribution/demo_results
# python demo.py \
# --config ./config/fashion_512.yaml \
# --which_iter 495400 \
# --name fashion_512 \
# --file_pairs ./txt_files/demo.txt \
# --input_dir ./demo_images \
# --output_dir $PATH_TO_OUTPUT
# Out:
# net [net_G] parameter count: 42,612,402
# net [net_D] parameter count: 26,885,697
# Setup trainer.
# Perceptual loss:
# 	Mode: vgg19
# GAN mode: style_gan2
# Perceptual loss:
# 	Mode: vgg19
# Loss perceptual           Weight 1
# Loss attn_rec             Weight 15
# Loss gan                  Weight 1.5
# Loss face                 Weight 1
# load [net_G_ema] from result/fashion_512/epoch_00200_iteration_000495400_checkpoint.pt
# Done with loading the checkpoint.
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:09<00:00, 60.2MB/s]
# 32it [00:23,  1.37it/s]

# %% [markdown]
# # Appearance Control

# %%
# %%bash
# pip install mmcv==0.5.1
# pip install pycocotools==2.0.4
# pip install ipykernel

# %%
# %%bash
# cd Neural-Texture-Extraction-Distribution/scripts
# chmod +x insert_mmfashion2mmdetection.sh
# ./insert_mmfashion2mmdetection.sh
# cd ../third_part/mmdetection
# pip install -v -e .

# %%
# %%bash
# cd Neural-Texture-Extraction-Distribution/
# python appearance_control.py \
# --config ./config/fashion_512.yaml \
# --name fashion_512 \
# --which_iter 495400 \
# --input_dir ./demo_images \
# --file_pairs ./txt_files/appearance_control.txt
